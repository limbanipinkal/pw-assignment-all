# %% [markdown]
# <a href="https://colab.research.google.com/github/limbanipinkal/pw-assignment-all/blob/main/statistics_practice_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## statistics practice questiona ##

# %%
Q=1. Generate a list o> R00 integers containing values between 90 to R30 and store it in the variable `int_list`.
A>ter generating the list, >ind the >ollowing


  (i) Write a Python function to calculate the mean of a given list of numbers.

Create a function to find the median of a list of numbers
if len(numbers) % 2 == 0:
    return (numbers[len(numbers)//2] + numbers[len(numbers)//2 - 1])/2
  else:
    return numbers[len(numbers)//2]

  2. (ii) Develop a program to compute the mode of a list of integers
     def mode(numbers):
  c = Counter(numbers)
  return [k for k, v in c.items() if v == c.most_common(1)[0][1]]

3.

  (iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights
  def weighted_mean(values, weights):
  return sum(value * weight for value, weight in zip(values, weights)) / sum(weights)

 4.   (iv) Write a Python function to find the geometric mean of a list of positive number
  import math
  def geometric_mean(numbers):
  return math.prod(numbers) ** (1/len(numbers))

 5.(v) Create a program to calculate the harmonic mean of a list of values.
  def harmonic_mean(numbers):
  return len(numbers) / sum(1/number for number in numbers)

  6.Build a function to determine the midrange of a list of numbers (average of the minimum and maximum).
  def midrange(numbers):
  return (min(numbers) + max(numbers)) / 2

  7. Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of
outliers
  def trimmed_mean(numbers, trim_percentage):
  sorted_numbers = sorted(numbers)
  trimmed_numbers = sorted_numbers[trim_percentage:-trim_percentage]
  return sum(trimmed_numbers) / len(trimmed_numbers)

# %%
from typing_extensions import TYPE_CHECKING
2.2. Generate a list o> 500 integers containing values between 200 to 300 and store it in the variable `int_list2`.
A>ter generating the list, >ind the >ollowin

1.(i) Compare the given list of visualization for the given data
1. Frequency & Gaussian distribution:

-this likely refers to plotting a histogram to show the
frequency of data point alongside a Theoretical gaussian normal distribution curve.
-this helps visually assess how well your data first a normal distribution.

    2. Frequency smoothened KDE plot:

  -this involves using kernal density estimation to create a smoothed
  representation of the data distribution.kde can be more informative
  than the histogram as it doesnt rely on rigid bins. smoothing further
  inhence the visual appeal and can highlight the overall shape of the distribution..

    3. Gaussian distribution & smoothened KDE plo:

    -this combines a kde plot with a gaussian curve this allow for a direct comparison
    of the estimated distribution from your data .config/


    (ii) Write a Python function to calculate the range of a given list of numbers
         ef find_range(numbers):
  return max(numbers) - min(numbers)

    (iii) Create a program to find the variance and standard deviation of a list of numbers
    def variance(numbers):
  mean = sum(numbers) / len(numbers)
  return sum((number - mean) ** 2 for number in numbers) / (len(numbers) - 1)


  def standard_deviation(numbers):
  return variance(numbers) ** 0.5

    (iv) Implement a function to compute the interquartile range (IQR) of a list of values.
    def interquartile_range(numbers):
  q1, q3 = quantile(numbers, [0.25, 0.75])
  return q3 - q1

   (v) Build a program to calculate the coefficient of variation for a dataset
   def coefficient_of_variation(numbers):
  return standard_deviation(numbers) / mean(numbers)


    (vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.
    def mean_absolute_deviation(numbers):
  mean = sum(numbers) / len(numbers)
  return sum(abs(number - mean) for number in numbers) / len(numbers)


  (vii) Create a program to calculate the quartile deviation of a list of values.

  def quartile_deviation(numbers):
  q1, q3 = quantile(numbers, [0.25, 0.75])
  return 1.5 * (q3 - q1)


  (viii) Implement a function to find the range-based coefficient of dispersion for a dataset.
  def range_coefficient_of_dispersion(numbers):
  return range(numbers) / mean(numbers)

# %%
3. Write a P
thon class representing a discrete random variable with methods to calculate its expected
value and variance

 def __init__(self, values, probabilities):
    self.values = values
    self.probabilities = probabilities

  def expected_value(self):
    return sum([value * probability for value, probability in zip(self.values, self.probabilities)])

  def variance(self):
    expected_value = self.expected_value()
    return sum([probability * (value - expected_value)**2 for value, probability in zip(self.values, self.probabilities)])

# %%
4.) Implement a program to simulate the rolling o6 a 6air six-sided die and calculate the expected value and
variance o6 the outcomes
num_rolls = 1000
outcomes = roll_dice(num_rolls)
print(f"Expected Value: {expected_value(outcomes)}")
print(f"Variance: {variance(outcomes)}")

# %%
5.) Create a P
thon 6unction to generate random samples 6rom a given probabilit
 distribution (e.g.,
binomial, Poisson) and calculate their mean and variance

mean, variance = generate_samples(distribution='binomial', n=10, p=0.5, size=1000)
print(f"Mean: {mean}")
print(f"Variance: {variance}")

# %%
6.}) Write a P
thon script to generate random numbers 6rom a Gaussian (normal) distribution and compute
the mean, variance, and standard deviation o6 the samples

mean = 0
std_dev = 1
sample_size = 1000

# Generate random samples from the normal distribution
samples = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate the mean, variance, and standard deviation
mean = np.mean(samples)
variance = np.var(samples)
std_deviation = np.std(samples)


print(f"Mean: {mean}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_deviation}")

# %%
# Use seaborn library to load tips dataset. Find the following from the dataset for the columns total_bill and tip

# %%
import seaborn as sns
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
def calculate_skewness(data):


  """
  Calculates the skewness of a dataset.

  Args:
    data: A list or array of numerical values.

  Returns:
    The skewness of the data.
  """
  return np.skew(data)

# %%
# Create a program that determines whether the columns exhibit positive skewness, negative skewness, or are approximately symmetric

import seaborn as sns


tips = sns.load_dataset('tips')

# Calculate the skewness of total_bill and tip
skewness_total_bill = tips['total_bill'].skew()
skewness_tip = tips['tip'].skew()

# Determine the skewness type
if skewness_total_bill > 0:
  skewness_type_total_bill = "Positive Skewness"
elif skewness_total_bill < 0:
  skewness_type_total_bill = "Negative Skewness"
else:
  skewness_type_total_bill = "Approximately Symmetric"

if skewness_tip > 0:
  skewness_type_tip = "Positive Skewness"
elif skewness_tip < 0:
  skewness_type_tip = "Negative Skewness"
else:
  skewness_type_tip = "Approximately Symmetric"

# Print the results
print(f"Total Bill Skewness: {skewness_total_bill}, {skewness_type_total_bill}")
print(f"Tip Skewness: {skewness_tip}, {skewness_type_tip}")
# Out:
# Total Bill Skewness: 1.1332130376158205, Positive Skewness
# Tip Skewness: 1.4654510370979401, Positive Skewness

# %%
# Write a function that calculates the covariance between two columns
import seaborn as sns
import numpy as np
tips=sns.load_dataset('tips')
data=tips
def calculate_covariance(data, column1, column2):
  """
  Calculates the covariance between two columns of a dataset.

  Args:
    data:('tips')
    column1: The name of the first column.
    column2: The name of the second column.

  Returns:
    The covariance between the two columns.
  """
  return np.cov(data[column1], data[column2])[0, 1]

# %%
# Implement a Python program that calculates the Pearson correlation coefficient between two columns.

import seaborn as sns
tips=sns.load_dataset('tips')
data=tips
def calculate_pearson_correlation(data, column1, column2):
  """
  Calculates the Pearson correlation coefficient between two columns of a dataset.

  Args:
    data('tips')
    column1: The name of the first column.
    column2: The name of the second column.

  Returns:
    The Pearson correlation coefficient between the two columns.
  """
  correlation = np.corrcoef(data[column1], data[column2])[0, 1]
  return correlation

# %%
# Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using
# scatter plots.

import pandas as pd
import matplotlib.pyplot as plt

def visualize_correlation(data, column1, column2):
  """
  Visualizes the correlation between two specific columns in a Pandas DataFrame using scatter plots.

  Args:
    data: A pand
    column1: The name of the first column.
    column2: The name of the second column.
  """

  plt.figure(figsize=(8, 6))
  plt.scatter(data[column1], data[column2])
  plt.xlabel(column1)
  plt.ylabel(column2)
  plt.title(f"Scatter plot of {column1} vs. {column2}")
  plt.show()

# %%
"""Write a Python function to calculate the probability density function (PDF) of a continuous random
variable for a given normal distribution"""


import scipy.stats as stats

def calculate_pdf(x, mean, std_dev):
  """
  Calculates the probability density function (PDF) of a continuous random variable
  for a given normal distribution.

  Args:
    x: The value of the random variable.
    mean: The mean of the normal distribution.
    std_dev: The standard deviation of the normal distribution.

  Returns:
    The PDF value at x.
  """

  pdf = stats.norm.pdf(x, loc=mean, scale=std_dev)
  return pdf

# %%
9. Create a program to calculate the cumulative distribution 6unction (CDF) o6 exponential distribution
import scipy.stats as stats

def calculate_cdf_exponential(x, lambda_):
  """
  Calculates the cumulative distribution function (CDF) of the exponential distribution.

  Args:
    x: The value of the random variable.
    lambda_: The rate parameter of the exponential distribution.

  Returns:
    The CDF value at x.
  """

  cdf = stats.expon.cdf(x, scale=1/lambda_)
  return cdf

# %%
10.ÕÐ) Write a P
thon 6unction to calcul
ate the probabilit
 mass 6unction (PMF) o6 Poisson distribution

pmf_value = calculate_pmf_poisson(k, mu)
print(f"PMF at k = {k}: {pmf_value}")

# %%
11. A company wants to test iN a new website layout leads to a higher conversion rate (percentage oN visitors
who make a purchase). They collect data Nrom the old and new layouts to compare


to ge<erate the data use the followi<g comma<d:

```python

import <umpy as <p

# 50 purchases out of 1000 visitors

old_layout = <p.array([1] * 50 + [0] * 950)

# 70 purchases out of 1000 visitors

<ew_layout = <p.array([1] * 70 + [0] * 930)

  ```

Apply z-test to fi<d which layout is successfu




import numpy as np
# !pip install statsmodels
from statsmodels.stats.proportion import proportions_ztest

# Data (as provided)
old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)

# Calculate conversions and total visitors
conversions_old = np.sum(old_layout)
visitors_old = len(old_layout)
conversions_new = np.sum(new_layout)
visitors_new = len(new_layout)

# Perform two-proportion z-test
count = np.array([conversions_old, conversions_new])
nobs = np.array([visitors_old, visitors_new])
stat, pval = proportions_ztest(count, nobs, alternative='smaller')

print(f"Z-statistic: {stat:.4f}")
print(f"P-value: {pval:.4f}")

# Interpret results
alpha = 0.05  # Significance level
if pval < alpha:
    print("Reject null hypothesis - New layout has a statistically significant higher conversion rate.")
else:
    print("Fail to reject null hypothesis - No statistically significant difference in conversion rates.")

# %%
12. A tutoring service claims that its program improves students' exam scores. A sample oN students who
participated in the program was taken, and their scores beNore and aNter the program were recorded

Use the below code to ge<erate samples of respective arrays of marks:

```python

before_program = <p.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])

after_program = <p.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

```

Use z-test to fi<d if the claims made by tutor are true or false.






import numpy as np
from scipy import stats

before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

# Perform paired t-test
t_stat, p_value = stats.ttest_rel(before_program, after_program)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - Tutoring program has a statistically significant effect on exam scores.")
else:
    print("Fail to reject null hypothesis - No statistically significant effect of tutoring program.")

# %%
# 13. A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They
# conduct a study and record blood pressure measurements before and after administering the drug.
# Use the below code to generate samples of respective arrays of blood pressure:
import numpy as np
from scipy import stats
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])

after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])


Impleme<t z-test to fi<d if the drug really works or <ot


Use the below code to ge<erate samples of respective arrays of blood pressure:


```python

before_drug = <p.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])

after_drug = <p.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

  ```


Impleme<t z-test to fi<d if the drug really works or <not
# Out:
#   File "<ipython-input-40-2d25a99c7aab>", line 11
#     Impleme<t z-test to fi<d if the drug really works or <ot
#               ^
# SyntaxError: invalid syntax

# %%
14. A custo:er service depart:ent clai:s that their average response ti:e is less than 5 :inutesV A sa:ple
of recent custo:er interactions was taken, and the response ti:es were recorded


Impleme3t the below code to ge3erate the array of respo3se time:

import numpy as np
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])


Impleme3t z-test to fi3d the claims made by customer service departme3t are tru or false




import numpy as np
from scipy import stats

# Sample data (replace with your actual response times)
response_times = np.array([4.5, 3.8, 5.2, 4.1, 4.6, 3.9, 5.0, 4.3, 4.7, 4.2])

# Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(response_times, 5)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05  # Significance level
if p_value/2 < alpha:  # Divide p-value by 2 for a one-tailed test
    print("Reject null hypothesis - Average response time is likely less than 5 minutes.")
else:
    print("Fail to reject null hypothesis - No strong evidence that average response time is less than 5 minutes.")
# Out:
#   File "<ipython-input-42-9c2f048b31e5>", line 1
#     14. A custo:er service depart:ent clai:s that their average response ti:e is less than 5 :inutesV A sa:ple
#         ^
# SyntaxError: invalid syntax

# %%
A co:pany is testing two different website layouts to see which one leads to higher click-through ratesV
Write a Python function to perfor: an A/B test analysis, including calculating the t-statistic, degrees of
freedo:, and p-value


Use the followi3g data:

```python

layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]

layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]


import numpy as np
from scipy import stats

def ab_test(layout_a_clicks, layout_b_clicks):
  """
  Performs an A/B test analysis.

  Args:
    layout_a_clicks: A list of click-through rates for layout A.
    layout_b_clicks: A list of click-through rates for layout B.

  Returns:
    A tuple containing the t-statistic, degrees of freedom, and p-value.
  """

  t_stat, p_value = stats.ttest_ind(layout_a_clicks, layout_b_clicks)
  degrees_of_freedom = len(layout_a_clicks) + len(layout_b_clicks) - 2
  return t_stat, degrees_of_freedom, p_value

# Sample data
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

# Perform A/B test
t_stat, df, p_value = ab_test(layout_a_clicks, layout_b_clicks)

print(f"T-statistic: {t_stat:.4f}")
print(f"Degrees of freedom: {df}")
print(f"P-value: {p_value:.4f}")

# %%
16. A phar:aceutical co:pany wants to deter:ine if a new drug is :ore effective than an existing drug in
reducing cholesterol levelsV Create a progra: to analyze the clinical trial data and calculate the tstatistic and p-value for the treat:ent ef

Use the followi3g data of cholestrol level:

```python

existi3g_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]

3ew_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

``


import numpy as np
from scipy import stats

existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

# Perform independent samples t-test
t_stat, p_value = stats.ttest_ind(existing_drug_levels, new_drug_levels)

print(f"T-statistic: {t_stat:.4f}")
print(f'p_value: {p_value:.4f}')

# %%
A school district introduces an educational intervention progra: to i:prove :ath scoresV Write a Python
function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to
deter:ine if the intervention had a significant i:pact


Use the followi3g data of test score:


  ```python

  pre_i3terve3tio3_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]

  post_i3terve3tio3_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

  ``




mport numpy as np
from scipy import stats

pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

# Perform paired samples t-test
t_stat, p_value = stats.ttest_rel(pre_intervention_scores, post_intervention_scores)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# %%
18..an HR department wants to investigate i@ there's a gender-based salary gap within the company. Develop
a program to analyze salary data, calculate the t-statistic, and determine i@ there's a statistically
signi@icant di@@erence between the average salaries o@ male and @emale employees


Use the below code to generate synthetic dataY
```python

# Generate synthetic salary data for male and female employees

np.random.seed(0)  # For reproducibility

male_salaries = np.random.normal(loc=50000, scale=10000, size=20)

female_salaries = np.random.normal(loc=55000, scale=9000, size=20




 np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=60000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

  def analyze_salary_gap(male_salaries, female_salaries):
  """
  Analyzes salary data to determine if there's a gender-based salary gap.

  Args:
    male_salaries: A list of salaries for male employees.
    female_salaries: A list of salaries for female employees.

  Returns:
    A tuple containing the t-statistic and p-value.
  """

  t_stat, p_value = stats.ttest_ind(male_salaries, female_salaries)
  return t_stat, p_value

# Sample data (replace with actual salary data)
male_salaries = [60000, 65000, 70000, 55000, 62000, 68000, 75000, 63000, 67000, 72000]
female_salaries = [55000, 60000, 62000, 50000, 58000, 63000, 68000, 59000, 61000, 65000]

# Analyze salary gap
t_stat, p_value = analyze_salary_gap(male_salaries, female_salaries)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results (example)
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - There is a statistically significant salary gap.")
else:
    print("Fail to reject null hypothesis - No statistically significant salary gap.")

# %%
A manu@acturer produces two di@@erent versions o@ a product and wants to compare their quality scores.
Create a Python @unction to analyze quality assessment data, calculate the t-statistic, and decide
whether there's a signi@icant di@@erence in quality between the two versions

Use the following dataY
```python

version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]

version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]


import numpy as np
from scipy import stats

version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

# Perform independent samples t-test
t_stat, p_value = stats.ttest_ind(version1_scores, version2_scores)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results (example)
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - There is a significant difference in quality.")
else:
    print("Fail to reject null hypothesis - No significant difference in quality.")

# %%
20. A restaurant chain collects customer satis@action scores @or two di@@erent branches. Write a program to
analyze the scores, calculate the t-statistic, and determine i@ there's a statistically signi@icant di@@erence in
customer satis@action between the branches


Use the below data of scores:

  ```python

branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]

branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]




import numpy as np
from scipy import stats

branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

# Perform independent samples t-test
t_stat, p_value = stats.ttest_ind(branch_a_scores, branch_b_scores)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results (example)
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - There is a significant difference in customer satisfaction.")
else:
    print("Fail to reject null hypothesis - No significant difference in customer satisfaction.")

# %%
A political analyst wants to determine i@ there is a signi@icant association between age groups and voter
pre@erences FCandidate A or Candidate B). They collect data @rom a sample o@ 500 voters and classi@y
them into di@@erent age groups and candidate pre@erences. Per@orm a Chi-Square test to determine i@
there is a signi@icant association between age groups and voter pre@erences



Use the below code to generate data:

```python

np.random.seed(0)

age_groups = np.random.choice([ 18 30 , 31 50 , 51+', 51+'], size=30)

voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30




   import numpy as np
from scipy.stats import chi2_contingency

np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

# Create a contingency table
observed = pd.crosstab(age_groups, voter_preferences)

# Perform Chi-Square test
chi2, p_value, dof, expected = chi2_contingency(observed)

print(f"Chi-Square statistic: {chi2:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of freedom: {dof}")

# Interpret results (example)
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - There is a significant association between age groups and voter preferences.")
else:
    print("Fail to reject null hypothesis - No significant association between age groups and voter preferences.")

# %%
22. A company conducted a customer satisfaction survey to determine if there is a significant relationship
between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are
located (East, West, North, South). The survey data is summarized in a contingency table. Conduct a ChiSquare test to determine if there is a significant relationship between product satisfaction levels and
customer regions



Sample data:

```python

#Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)

data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

``

import numpy as np
from scipy.stats import chi2_contingency

# Sample data
data = np.array([[50, 30, 40, 20],
                 [30, 40, 30, 50],
                 [20, 30, 40, 30]])

# Perform Chi-Square test
chi2_stat, p_value, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of freedom: {dof}")

# Interpret results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - There is a significant relationship between satisfaction and region.")
else:
    print("Fail to reject null hypothesis - No significant relationship between satisfaction and region.")

# %%
23. A 23.company implemented an employee training program to improve job performance (Effective, Neutral,
Ineffective). After the training, they collected data from a sample of employees and classified them based
on their job performance before and after the training. Perform a Chi-Square test to determine if there is a
significant difference between job performance levels before and after the training




Sample data:

```python

# Sample data: Job performance levels before (rows) and after (columns) training

data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]]

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20],
                 [30, 40, 30],
                 [20, 30, 40]])

# Perform Chi-Square test
chi2_stat, p_value, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of freedom: {dof}")

# Interpret results (example)
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject null hypothesis - There is a significant difference in job performance before and after training.")
else:
    print("Fail to reject null hypothesis - No significant difference in job performance before and after training.")

# %%
24. A company produces three different versions of a product: Standard, Premium, and Deluxe. The
company wants to determine if there is a significant difference in customer satisfaction scores among the
three product versions. They conducted a survey and collected customer satisfaction scores for each
version from a random sample of customers. Perform an ANOVA test to determine if there is a significant
difference in customer satisfaction scores.


  Use the following data:

  ```python

  # Sample data: Customer satisfaction scores for each product version

  standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]

  premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

  deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

  `
import scipy.stats as stats

# Sample data
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# Perform ANOVA test
f_statistic, p_value = stats.f_oneway(standard_scores, premium_scores, deluxe_scores)

print(f"F-statistic: {f_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# %%
### complete  assignment ###
